# %% [markdown]
# ### Primary data analysis on Categorical Encoding Challenge -2

# %% [markdown]
# #### 1) Import the necessary libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
curr_path = os.getcwd()

# %%
curr_path
# Out:
# '/home/shrishail/workspace/Categorical Feature Encoding Challenge II'

# %%
input_path = os.path.join(curr_path,'input/')
input_path
# Out:
# '/home/shrishail/workspace/Categorical Feature Encoding Challenge II/input/'

# %%
df_train = pd.read_csv(input_path+'train.csv')

# %%
df_train.head()
# Out:
#    id  bin_0  bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2       nom_3  \
# 0   0    0.0    0.0    0.0     F     N   Red  Trapezoid  Hamster      Russia
# 1   1    1.0    1.0    0.0     F     Y   Red       Star  Axolotl         NaN
# 2   2    0.0    1.0    0.0     F     N   Red        NaN  Hamster      Canada
# 3   3    NaN    0.0    0.0     F     N   Red     Circle  Hamster     Finland
# 4   4    0.0    NaN    0.0     T     N   Red   Triangle  Hamster  Costa Rica
#
#    ...      nom_9 ord_0        ord_1     ord_2 ord_3 ord_4  ord_5  day month  \
# 0  ...  02e7c8990   3.0  Contributor       Hot     c     U     Pw  6.0   3.0
# 1  ...  f37df64af   3.0  Grandmaster      Warm     e     X     pE  7.0   7.0
# 2  ...        NaN   3.0          NaN  Freezing     n     P     eN  5.0   9.0
# 3  ...  f9d456e57   1.0       Novice  Lava Hot     a     C    NaN  3.0   3.0
# 4  ...  c5361037c   3.0  Grandmaster      Cold     h     C     OZ  5.0  12.0
#
#   target
# 0      0
# 1      0
# ...

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600000 entries, 0 to 599999
# Data columns (total 25 columns):
# id        600000 non-null int64
# bin_0     582106 non-null float64
# bin_1     581997 non-null float64
# bin_2     582070 non-null float64
# bin_3     581986 non-null object
# bin_4     581953 non-null object
# nom_0     581748 non-null object
# nom_1     581844 non-null object
# nom_2     581965 non-null object
# nom_3     581879 non-null object
# nom_4     581965 non-null object
# nom_5     582222 non-null object
# nom_6     581869 non-null object
# nom_7     581997 non-null object
# nom_8     582245 non-null object
# nom_9     581927 non-null object
# ord_0     581712 non-null float64
# ord_1     581959 non-null object
# ord_2     581925 non-null object
# ord_3     582084 non-null object
# ord_4     582070 non-null object
# ord_5     582287 non-null object
# day       582048 non-null float64
# month     582012 non-null float64
# target    600000 non-null int64
# ...

# %%
df_train.select_dtypes(object)
# Out:
#        bin_3 bin_4 nom_0      nom_1    nom_2       nom_3     nom_4      nom_5  \
# 0          F     N   Red  Trapezoid  Hamster      Russia   Bassoon  de4c57ee2
# 1          F     Y   Red       Star  Axolotl         NaN  Theremin  2bb3c3e5c
# 2          F     N   Red        NaN  Hamster      Canada   Bassoon  b574c9841
# 3          F     N   Red     Circle  Hamster     Finland  Theremin  673bdf1f6
# 4          T     N   Red   Triangle  Hamster  Costa Rica       NaN  777d1ac2c
# ...      ...   ...   ...        ...      ...         ...       ...        ...
# 599995     T     N   Red    Polygon  Axolotl       India  Theremin  014770cf0
# 599996     T     Y  Blue    Polygon      Dog  Costa Rica      Oboe        NaN
# 599997     F     Y   Red     Circle  Axolotl      Russia  Theremin  c7dc5d460
# 599998     F     Y   NaN    Polygon  Axolotl         NaN     Piano  4d7780407
# 599999     T     N  Blue   Triangle      Dog      Russia  Theremin  17f06e644
#
# ...

# %%
y = df_train.target+df_train.target
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 599995    0
# 599996    0
# 599997    0
# 599998    0
# 599999    0
# Name: target, Length: 600000, dtype: int64

# %%
cols_to_enc = df_train.select_dtypes(object).columns

# %%
cols_to_enc
# Out:
# Index(['bin_3', 'bin_4', 'nom_0', 'nom_1', 'nom_2', 'nom_3', 'nom_4', 'nom_5',
#        'nom_6', 'nom_7', 'nom_8', 'nom_9', 'ord_1', 'ord_2', 'ord_3', 'ord_4',
#        'ord_5'],
#       dtype='object')

# %%
'nom_0' in cols_to_enc
# Out:
# True

# %%
df_train[df_train.select_dtypes([np.number]).columns.tolist()]=df_train.select_dtypes([np.number]).fillna(-9999)

# %%
df_train
# Out:
#             id   bin_0   bin_1  bin_2 bin_3 bin_4 nom_0      nom_1    nom_2  \
# 0            0     0.0     0.0    0.0     F     N   Red  Trapezoid  Hamster
# 1            1     1.0     1.0    0.0     F     Y   Red       Star  Axolotl
# 2            2     0.0     1.0    0.0     F     N   Red        NaN  Hamster
# 3            3 -9999.0     0.0    0.0     F     N   Red     Circle  Hamster
# 4            4     0.0 -9999.0    0.0     T     N   Red   Triangle  Hamster
# ...        ...     ...     ...    ...   ...   ...   ...        ...      ...
# 599995  599995     0.0     1.0    0.0     T     N   Red    Polygon  Axolotl
# 599996  599996     1.0     0.0    0.0     T     Y  Blue    Polygon      Dog
# 599997  599997     0.0     0.0    0.0     F     Y   Red     Circle  Axolotl
# 599998  599998     1.0     1.0    0.0     F     Y   NaN    Polygon  Axolotl
# 599999  599999     0.0     0.0    0.0     T     N  Blue   Triangle      Dog
#
# ...
